# %% [markdown]
# <a href="https://colab.research.google.com/github/Khizer2/test-repo/blob/master/NAMED_ENTITY_RECOGNITION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NAMED ENTITY RECOGNITION:
#
# 1. The named entities are pre-defined categories chosen according to the use case such as names of people, organizations, places, codes, time notations, monetary values, etc.
#
# 1. NER aims to assign a class to each token (usually a single word) in a sequence. Because of this, NER is also referred to as token classification.

# %%
# !pip install simpletransformers
# Out:
# ...
#      |████████████████████████████████| 215kB 17.5MB/s
# ...
#      |████████████████████████████████| 1.2MB 50.9MB/s
# ...
#      |████████████████████████████████| 122kB 55.1MB/s
# ...
#      |████████████████████████████████| 8.2MB 24.0MB/s
# ...
#      |████████████████████████████████| 2.1MB 53.6MB/s
# ...
#      |████████████████████████████████| 51kB 8.2MB/s
# ...
#      |████████████████████████████████| 81kB 11.2MB/s
# ...
#      |████████████████████████████████| 225kB 56.8MB/s
# ...
#      |████████████████████████████████| 3.3MB 45.9MB/s
# ...
#      |████████████████████████████████| 2.1MB 43.7MB/s
# ...
#      |████████████████████████████████| 112kB 57.3MB/s
# ...
#      |████████████████████████████████| 4.2MB 45.6MB/s
# ...
#      |████████████████████████████████| 163kB 51.3MB/s
# ...
#      |████████████████████████████████| 81kB 10.0MB/s
# ...
#      |████████████████████████████████| 102kB 11.6MB/s
# ...
#      |████████████████████████████████| 133kB 56.4MB/s
# ...
#      |████████████████████████████████| 245kB 57.2MB/s
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-68cd745d-5d02-413b-ac66-20ec7d9b82f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68cd745d-5d02-413b-ac66-20ec7d9b82f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
import pandas as pd
data = pd.read_csv("train.csv",encoding="latin1" )
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head(30)
# Out:
#     sentence_id       column1 tag
# 0             0   Requisition   O
# 1             0            ID   O
# 2             0             :   O
# 3             0        217281   O
# 4             0          Work   O
# 5             0          Area   O
# 6             0             :   O
# 7             0      Software   O
# 8             0             -   O
# 9             0        Design   O
# 10            0           and   O
# 11            0   Development   O
# 12            0      Expected   O
# 13            0        Travel   O
# 14            0             :   O
# 15            0             0   O
# 16            0             -   O
# 17            0            10   O
# 18            0             %   O
# 19            0        Career   O
# 20            0        Status   O
# 21            0             :   O
# 22            0  Professional   O
# 23            0    Employment   O
# 24            0          Type   O
# 25            0             :   O
# ...

# %%
data =data.fillna(method ="ffill")

# %%
data.head(30)
# Out:
#     sentence_id       column1 tag
# 0             0   Requisition   O
# 1             0            ID   O
# 2             0             :   O
# 3             0        217281   O
# 4             0          Work   O
# 5             0          Area   O
# 6             0             :   O
# 7             0      Software   O
# 8             0             -   O
# 9             0        Design   O
# 10            0           and   O
# 11            0   Development   O
# 12            0      Expected   O
# 13            0        Travel   O
# 14            0             :   O
# 15            0             0   O
# 16            0             -   O
# 17            0            10   O
# 18            0             %   O
# 19            0        Career   O
# 20            0        Status   O
# 21            0             :   O
# 22            0  Professional   O
# 23            0    Employment   O
# 24            0          Type   O
# 25            0             :   O
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data["sentence_id"] = LabelEncoder().fit_transform(data["sentence_id"] )

# %%
data.head(30)
# Out:
#     sentence_id       column1 tag
# 0             0   Requisition   O
# 1             0            ID   O
# 2             0             :   O
# 3             0        217281   O
# 4             0          Work   O
# 5             0          Area   O
# 6             0             :   O
# 7             0      Software   O
# 8             0             -   O
# 9             0        Design   O
# 10            0           and   O
# 11            0   Development   O
# 12            0      Expected   O
# 13            0        Travel   O
# 14            0             :   O
# 15            0             0   O
# 16            0             -   O
# 17            0            10   O
# 18            0             %   O
# 19            0        Career   O
# 20            0        Status   O
# 21            0             :   O
# 22            0  Professional   O
# 23            0    Employment   O
# 24            0          Type   O
# 25            0             :   O
# ...

# %%
data.rename(columns={"column1":"words","tag":"labels"}, inplace =True)

# %%
data.rename
# Out:
# <bound method DataFrame.rename of          sentence_id        words labels
# 0                  0  Requisition      O
# 1                  0           ID      O
# 2                  0            :      O
# 3                  0       217281      O
# 4                  0         Work      O
# ...              ...          ...    ...
# 1048570            0            .      O
# 1048571            0            .      O
# 1048572            0            .      O
# 1048573            0            .      O
# 1048574            0            .      O
#
# [1048575 rows x 3 columns]>

# %%
data["labels"] = data["labels"].str.upper()

# %%
X= data[["sentence_id","words"]]
Y =data["labels"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size =0.2)

# %%
#building up train data and test data
train_data = pd.DataFrame({"sentence_id":x_train["sentence_id"],"words":x_train["words"],"labels":y_train})
test_data = pd.DataFrame({"sentence_id":x_test["sentence_id"],"words":x_test["words"],"labels":y_test})

# %%
train_data
# Out:
#         sentence_id         words labels
# 395007            0             .      O
# 241196            0             .      O
# 268442            0             .      O
# 150716            0          make      O
# 787961            0             .      O
# ...             ...           ...    ...
# 371446            0             .      O
# 130855            0             /      O
# 825769            0             .      O
# 113870            0  professional      O
# 788551            0             .      O
#
# [838860 rows x 3 columns]

# %%
test_data
# Out:
#          sentence_id words labels
# 63164              0    to      O
# 991599             0     .      O
# 1033975            0     .      O
# 121063             0   day      O
# 264307             0     .      O
# ...              ...   ...    ...
# 862205             0     .      O
# 221509             0     ,      O
# 595825             0     .      O
# 287153             0     .      O
# 276908             0     .      O
#
# [209715 rows x 3 columns]

# %% [markdown]
# # Model Training

# %%
from simpletransformers.ner import NERModel,NERArgs

# %%
label = data["labels"].unique().tolist()
label
# Out:
# ['O', 'SOFT', 'SAP', 'TECH']

# %%
args = NERArgs()
args.num_train_epochs = 1
args.learning_rate = 1e-4
args.overwrite_output_dir =True
args.train_batch_size = 32
args.eval_batch_size = 32

# %%
model = NERModel('bert', 'bert-base-cased',labels=label,args =args)
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForTokenClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
model.train_model(train_data,eval_data = test_data,acc=accuracy_score)
# Out:
# ...
# Running Epoch 0 of 1:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# (1, 1.7479139566421509)

# %%
result, model_outputs, preds_list = model.eval_model(test_data)
# Out:
# ...
# Running Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SOFT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SAP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: TECH seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))

# %%
result
# Out:
# {'eval_loss': 1.6241059303283691,
#  'f1_score': 0.033898305084745756,
#  'precision': 0.017543859649122806,
#  'recall': 0.5}

# %%
prediction, model_output = model.predict(["I am good in python programming"])
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prediction
# Out:
# [[{'I': 'O'},
#   {'am': 'TECH'},
#   {'good': 'O'},
#   {'in': 'TECH'},
#   {'python': 'O'},
#   {'programming': 'O'}]]
